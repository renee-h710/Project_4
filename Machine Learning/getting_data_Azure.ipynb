# %%
import pandas as pd 
import pandas.io.sql as sqlio
import psycopg2

# %%
conn = psycopg2.connect(database="postgres",
                        host="realestate-server-pg.postgres.database.azure.com",
                        user="postgresADM",
                        password="cB3uJQs74mEG$gQ",
                        port="5432")

# %%
cursor = conn.cursor()

# %%
variable = "SELECT * FROM housing"

# %%
df = sqlio.read_sql_query(variable, conn)
# Out:
# /Users/kaylagranados/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df
# Out:
#       id    price  area  bedrooms  bathrooms  stories guestroom basement  \
# 0      1  9100000  6000         4          1        2        no      yes
# 1      2  9100000  6600         4          2        2       yes      yes
# 2      3  8960000  8500         3          2        4        no       no
# 3      4  8890000  4600         3          2        2       yes       no
# 4      5  8855000  6420         3          2        2        no       no
# ..   ...      ...   ...       ...        ...      ...       ...      ...
# 525  526  1820000  3000         2          1        1        no      yes
# 526  527  1767150  2400         3          1        1        no       no
# 527  528  1750000  3620         2          1        1        no       no
# 528  529  1750000  2910         3          1        1        no       no
# 529  530  1750000  3850         3          1        2        no       no
#
#     hotwaterheating airconditioning  parking prefarea
# ...
